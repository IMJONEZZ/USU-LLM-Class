# %%
import pandas as pd

df = pd.read_json(
    "hf://datasets/andrewkroening/Star-wars-scripts-dialogue-IV-VI/SW_EpisodeIV_VI.json"
)

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\jasho\\Desktop\\MS STAT\\Spring25\\DSAI 6810\\Class github\\USU-LLM-Class'

# %%
df.to_json("C:\\Users\\jasho\\Desktop\\MS STAT\\Spring25\\DSAI 6810\\star-wars.json")

# %%
df = pd.read_json(
    "C:\\Users\\jasho\\Desktop\\MS STAT\\Spring25\\DSAI 6810\\star-wars.json"
)
display(df)
# Out:
#      Character                                               Line
# 0     THREEPIO  Did you hear that?  They've shut down the main...
# 1     THREEPIO                                      We're doomed!
# 2     THREEPIO  There'll be no escape for the Princess this time.
# 3     THREEPIO                                       What's that?
# 4     THREEPIO  I should have known better than to trust the l...
# ...        ...                                                ...
# 2518     LANDO       Wedge, I don't think we're going to make it.
# 2519     WEDGE        You'll make it. Just follow me Gold Leader.
# 2520     LANDO  I promised to return his ship without a scratc...
# 2521       HAN                                           Lando...
# 2522  THREEPIO                                       They did it!
#
# [2523 rows x 2 columns]
