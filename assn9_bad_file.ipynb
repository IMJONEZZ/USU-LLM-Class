# %%
# %%capture
# Skip restarting message in Colab
import sys

modules = list(sys.modules.keys())
for x in modules:
    sys.modules.pop(x) if "PIL" in x or "google" in x else None


! pip install guidance==0.1.9 transformers accelerate bitsandbytes

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n)
# Token is valid (permission: read).
# The token `colab-llama3` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `colab-llama3`

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from guidance import models
import guidance

# Model from Hugging Face
model_name = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# Load model + tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name, torch_dtype="auto", device_map="auto"
)

# Set up Guidance
llm = models.Transformers(model=model, tokenizer=tokenizer)
guidance.llm = llm
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu and disk.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-29b7750bd088> in <cell line: 0>()
#      21 from guidance import gen
#      22
# ---> 23 program = guidance("""
#      24 Q: Who won the last Kentucky derby and by how much?
#      25 A: {{gen 'answer' stop='Q:'}}
#
# /usr/local/lib/python3.11/dist-packages/guidance/__init__.py in __call__(self, f, stateless, cache, dedent, model)
#      22 class Guidance(types.ModuleType):
#      23     def __call__(self, f=None, *, stateless=False, cache=None, dedent=True, model=models.Model):
# ---> 24         return _decorator(f, stateless=stateless, cache=cache, dedent=dedent, model=model)
#      25 sys.modules[__name__].__class__ = Guidance
#      26
#
# /usr/local/lib/python3.11/dist-packages/guidance/__init__.py in _decorator(f, stateless, cache, dedent, model)
#      40         # this strips out indentation in multiline strings that aligns with the current python indentation
#      41         if dedent is True or dedent == 'python':
# ---> 42             f = strip_multiline_string_indents(f)
#      43
#      44         # we cache if requested
#
# /usr/local/lib/python3.11/dist-packages/guidance/_utils.py in strip_multiline_string_indents(f)
#      73 def strip_multiline_string_indents(f):
#      74
# ---> 75     source = textwrap.dedent(inspect.getsource(f))
#      76     blanks = '\n' * f.__code__.co_firstlineno # padd the source so the lines in the file line up for the debugger
#      77     source = blanks + '\n'.join(source.splitlines()[1:]) # remove the decorator first line.
#
# /usr/lib/python3.11/inspect.py in getsource(object)
#    1256     or code object.  The source code is returned as a single string.  An
#    1257     OSError is raised if the source code cannot be retrieved."""
# -> 1258     lines, lnum = getsourcelines(object)
#    1259     return ''.join(lines)
#    1260
#
# /usr/lib/python3.11/inspect.py in getsourcelines(object)
#    1238     raised if the source code cannot be retrieved."""
#    1239     object = unwrap(object)
# -> 1240     lines, lnum = findsource(object)
#    1241
#    1242     if istraceback(object):
#
# /usr/lib/python3.11/inspect.py in findsource(object)
#    1057     is raised if the source code cannot be retrieved."""
#    1058
# -> 1059     file = getsourcefile(object)
#    1060     if file:
#    1061         # Invalidate cache if needed.
#
# /usr/lib/python3.11/inspect.py in getsourcefile(object)
#     934     Return None if no way can be identified to get the source.
#     935     """
# --> 936     filename = getfile(object)
#     937     all_bytecode_suffixes = importlib.machinery.DEBUG_BYTECODE_SUFFIXES[:]
#     938     all_bytecode_suffixes += importlib.machinery.OPTIMIZED_BYTECODE_SUFFIXES[:]
#
# /usr/local/lib/python3.11/dist-packages/torch/package/package_importer.py in _patched_getfile(object)
#     729         if object.__module__ in _package_imported_modules:
#     730             return _package_imported_modules[object.__module__].__file__
# --> 731     return _orig_getfile(object)
#     732
#     733
#
# /usr/lib/python3.11/inspect.py in getfile(object)
#     914     if iscode(object):
#     915         return object.co_filename
# --> 916     raise TypeError('module, class, method, function, traceback, frame, or '
#     917                     'code object was expected, got {}'.format(
#     918                     type(object).__name__))
#
# TypeError: module, class, method, function, traceback, frame, or code object was expected, got str

# %%
# Create and run a program
from guidance import gen

program = guidance("""
Q: Who won the last Kentucky derby and by how much?
A: {{gen 'answer' stop='Q:'}}
""")

result = program()
print(str(result))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-679cf0e40782> in <cell line: 0>()
#       2 from guidance import gen
#       3
# ----> 4 program = guidance("""
#       5 Q: Who won the last Kentucky derby and by how much?
#       6 A: {{gen 'answer' stop='Q:'}}
#
# /usr/local/lib/python3.11/dist-packages/guidance/__init__.py in __call__(self, f, stateless, cache, dedent, model)
#      22 class Guidance(types.ModuleType):
#      23     def __call__(self, f=None, *, stateless=False, cache=None, dedent=True, model=models.Model):
# ---> 24         return _decorator(f, stateless=stateless, cache=cache, dedent=dedent, model=model)
#      25 sys.modules[__name__].__class__ = Guidance
#      26
#
# /usr/local/lib/python3.11/dist-packages/guidance/__init__.py in _decorator(f, stateless, cache, dedent, model)
#      40         # this strips out indentation in multiline strings that aligns with the current python indentation
#      41         if dedent is True or dedent == 'python':
# ---> 42             f = strip_multiline_string_indents(f)
#      43
#      44         # we cache if requested
#
# /usr/local/lib/python3.11/dist-packages/guidance/_utils.py in strip_multiline_string_indents(f)
#      73 def strip_multiline_string_indents(f):
#      74
# ---> 75     source = textwrap.dedent(inspect.getsource(f))
#      76     blanks = '\n' * f.__code__.co_firstlineno # padd the source so the lines in the file line up for the debugger
#      77     source = blanks + '\n'.join(source.splitlines()[1:]) # remove the decorator first line.
#
# /usr/lib/python3.11/inspect.py in getsource(object)
#    1256     or code object.  The source code is returned as a single string.  An
#    1257     OSError is raised if the source code cannot be retrieved."""
# -> 1258     lines, lnum = getsourcelines(object)
#    1259     return ''.join(lines)
#    1260
#
# /usr/lib/python3.11/inspect.py in getsourcelines(object)
#    1238     raised if the source code cannot be retrieved."""
#    1239     object = unwrap(object)
# -> 1240     lines, lnum = findsource(object)
#    1241
#    1242     if istraceback(object):
#
# /usr/lib/python3.11/inspect.py in findsource(object)
#    1057     is raised if the source code cannot be retrieved."""
#    1058
# -> 1059     file = getsourcefile(object)
#    1060     if file:
#    1061         # Invalidate cache if needed.
#
# /usr/lib/python3.11/inspect.py in getsourcefile(object)
#     934     Return None if no way can be identified to get the source.
#     935     """
# --> 936     filename = getfile(object)
#     937     all_bytecode_suffixes = importlib.machinery.DEBUG_BYTECODE_SUFFIXES[:]
#     938     all_bytecode_suffixes += importlib.machinery.OPTIMIZED_BYTECODE_SUFFIXES[:]
#
# /usr/local/lib/python3.11/dist-packages/torch/package/package_importer.py in _patched_getfile(object)
#     729         if object.__module__ in _package_imported_modules:
#     730             return _package_imported_modules[object.__module__].__file__
# --> 731     return _orig_getfile(object)
#     732
#     733
#
# /usr/lib/python3.11/inspect.py in getfile(object)
#     914     if iscode(object):
#     915         return object.co_filename
# --> 916     raise TypeError('module, class, method, function, traceback, frame, or '
#     917                     'code object was expected, got {}'.format(
#     918                     type(object).__name__))
#
# TypeError: module, class, method, function, traceback, frame, or code object was expected, got str
