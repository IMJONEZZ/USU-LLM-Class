# %%
from agent import *

# %%
lm = dspy.LM('openai/gpt-4o-mini', api_key = API_KEY)

dspy.settings.configure(lm = lm)

# %%
# Run the agent

agent = ConditionalAgent()


question1 = "What do you think of the new game DustBlood from FS? It’s only available on NS2."
question2 = "After watching the trailer for DustBlood, it feels like a mix of Elden Ring and Bloodborne—I'm really excited about it! Do you think it'll be a good game?"

print("----- EXAMPLE 1 -----")
print(agent(question1))
print("\n----- EXAMPLE 2 -----")
print(agent(question2))
# Out:
# ----- EXAMPLE 1 -----
# DustBlood from FS has received positive feedback for its engaging gameplay and unique mechanics, especially considering it's exclusive to NS2. Players appreciate the immersive graphics and the depth of the storyline, which adds to the overall experience. However, some users have noted that the game may have a steep learning curve for newcomers. Overall, it seems to be a promising addition to the gaming landscape on NS2.
#
# ----- EXAMPLE 2 -----
# ...
